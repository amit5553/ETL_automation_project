# %% [markdown]
# Day 2

# %%
import pandas as pd

# %%
df=pd.read_csv('emp.csv',delimiter=',',usecols=['eno','ename','doj'])

# %%
df
# Out:
#     eno    ename         doj
# 0    10    Amber  2018-05-14
# 1     2     Amar  2017-03-22
# 2     8    Sagar  2020-11-30
# 3     4   Thomas  2019-08-18
# 4     5     Jade  2021-02-10
# 5     6    Smith  2016-12-01
# 6     7   Robert  2023-06-25
# 7     3     Nick  2015-09-15
# 8     9    Naman  2020-01-20
# 9     1    Vikas  2017-10-03
# 10   11   Dennis  2024-01-05
# 11   12    Karan  2018-06-16
# 12   13   Simran  2019-12-19
# 13   14     Amit  2022-04-09
# 14   15     Neha  2021-07-22
# 15   16    Rahul  2016-03-28
# 16   17    Divya  2015-11-11
# 17   18   Rakesh  2020-09-04
# 18   19   Monica  2023-08-07
# 19   20     John  2018-10-29
# 20   21    Sneha  2022-12-14
# 21   22    David  2017-02-17
# 22   23    Anita  2019-05-21
# 23   24    Vinod  2016-07-30
# 24   25    Meena  2020-03-13
# 25   26    Harsh  2021-09-25
# 26   27   Kavita  2019-01-06
# 27   28    Mohan  2015-04-17
# 28   29    Priya  2023-02-11
# 29   30   Suresh  2018-09-09
# 30   31     Rani  2022-11-03
# ...

# %%
col_name=['eno','ename']
df[col_name]
# Out:
#     eno    ename
# 0    10    Amber
# 1     2     Amar
# 2     8    Sagar
# 3     4   Thomas
# 4     5     Jade
# 5     6    Smith
# 6     7   Robert
# 7     3     Nick
# 8     9    Naman
# 9     1    Vikas
# 10   11   Dennis
# 11   12    Karan
# 12   13   Simran
# 13   14     Amit
# 14   15     Neha
# 15   16    Rahul
# 16   17    Divya
# 17   18   Rakesh
# 18   19   Monica
# 19   20     John
# 20   21    Sneha
# 21   22    David
# 22   23    Anita
# 23   24    Vinod
# 24   25    Meena
# 25   26    Harsh
# 26   27   Kavita
# 27   28    Mohan
# 28   29    Priya
# 29   30   Suresh
# 30   31     Rani
# 31   32     Ajay
# 32   33    Nidhi
# 33   34    Vivek
# 34   35    Seema
# 35   36     Ritu
# 36   37    Kunal
# 37   38     Alok
# 38   39   Poonam
# 39   40     Yash
# 40   41     Nina
# 41   42    Tarun
# 42   43    Geeta
# 43   44    Ashok
# 44   45  Sanjana
# 45   46    Manoj
# 46   47    Payal

# %%
df.head()
# Out:
#    eno   ename         doj
# 0   10   Amber  2018-05-14
# 1    2    Amar  2017-03-22
# 2    8   Sagar  2020-11-30
# 3    4  Thomas  2019-08-18
# 4    5    Jade  2021-02-10

# %%
index1=df.iloc[4]

# %%
type(index1)
# Out:
# pandas.core.series.Series

# %%
index1
# Out:
# eno               5
# ename          Jade
# doj      2021-02-10
# Name: 4, dtype: object

# %%
df.iloc[:2]
# Out:
#    eno  ename         doj
# 0   10  Amber  2018-05-14
# 1    2   Amar  2017-03-22

# %%
df.loc[:2]
# Out:
#    eno  ename         doj
# 0   10  Amber  2018-05-14
# 1    2   Amar  2017-03-22
# 2    8  Sagar  2020-11-30

# %%
df=pd.read_csv('emp.csv',delimiter=',',header=0,index_col='eno')

# %%
df
# Out:
#        ename  salary  deptno         doj
# eno
# 10     Amber    1000      10  2018-05-14
# 2       Amar    1000      10  2017-03-22
# 8      Sagar    1000      20  2020-11-30
# 4     Thomas    1000      10  2019-08-18
# 5       Jade    2000      10  2021-02-10
# 6      Smith    1000      10  2016-12-01
# 7     Robert    3000      20  2023-06-25
# 3       Nick    1000      30  2015-09-15
# 9      Naman    4000      30  2020-01-20
# 1      Vikas    1000      30  2017-10-03
# 11    Dennis   41000      30  2024-01-05
# 12     Karan    2200      20  2018-06-16
# 13    Simran    1500      10  2019-12-19
# 14      Amit    2000      30  2022-04-09
# 15      Neha    1700      20  2021-07-22
# 16     Rahul    1200      10  2016-03-28
# 17     Divya    3000      30  2015-11-11
# 18    Rakesh    1800      10  2020-09-04
# 19    Monica    2500      20  2023-08-07
# 20      John    2300      30  2018-10-29
# 21     Sneha    2700      10  2022-12-14
# 22     David    1000      20  2017-02-17
# ...

# %%
df.loc[:2]
# Out:
#      ename  salary  deptno         doj
# eno
# 10   Amber    1000      10  2018-05-14
# 2     Amar    1000      10  2017-03-22

# %%
df.loc[45:47]
# Out:
#        ename  salary  deptno         doj
# eno
# 45   Sanjana    1800      20  2023-03-17
# 46     Manoj    1700      30  2019-07-24
# 47     Payal    1600      20  2015-10-10

# %%
df.loc[10:15]
# Out:
#       ename  salary  deptno         doj
# eno
# 10    Amber    1000      10  2018-05-14
# 2      Amar    1000      10  2017-03-22
# 8     Sagar    1000      20  2020-11-30
# 4    Thomas    1000      10  2019-08-18
# 5      Jade    2000      10  2021-02-10
# 6     Smith    1000      10  2016-12-01
# 7    Robert    3000      20  2023-06-25
# 3      Nick    1000      30  2015-09-15
# 9     Naman    4000      30  2020-01-20
# 1     Vikas    1000      30  2017-10-03
# 11   Dennis   41000      30  2024-01-05
# 12    Karan    2200      20  2018-06-16
# 13   Simran    1500      10  2019-12-19
# 14     Amit    2000      30  2022-04-09
# 15     Neha    1700      20  2021-07-22

# %%
df.loc[45:47]
# Out:
#        ename  salary  deptno         doj
# eno
# 45   Sanjana    1800      20  2023-03-17
# 46     Manoj    1700      30  2019-07-24
# 47     Payal    1600      20  2015-10-10

# %%
df.iloc[45:47]
# Out:
#      ename  salary  deptno         doj
# eno
# 46   Manoj    1700      30  2019-07-24
# 47   Payal    1600      20  2015-10-10

# %%
df[['ename','doj']]
# Out:
#        ename         doj
# eno
# 10     Amber  2018-05-14
# 2       Amar  2017-03-22
# 8      Sagar  2020-11-30
# 4     Thomas  2019-08-18
# 5       Jade  2021-02-10
# 6      Smith  2016-12-01
# 7     Robert  2023-06-25
# 3       Nick  2015-09-15
# 9      Naman  2020-01-20
# 1      Vikas  2017-10-03
# 11    Dennis  2024-01-05
# 12     Karan  2018-06-16
# 13    Simran  2019-12-19
# 14      Amit  2022-04-09
# 15      Neha  2021-07-22
# 16     Rahul  2016-03-28
# 17     Divya  2015-11-11
# 18    Rakesh  2020-09-04
# 19    Monica  2023-08-07
# 20      John  2018-10-29
# 21     Sneha  2022-12-14
# 22     David  2017-02-17
# 23     Anita  2019-05-21
# 24     Vinod  2016-07-30
# 25     Meena  2020-03-13
# 26     Harsh  2021-09-25
# 27    Kavita  2019-01-06
# 28     Mohan  2015-04-17
# 29     Priya  2023-02-11
# 30    Suresh  2018-09-09
# 31      Rani  2022-11-03
# 32      Ajay  2020-06-26
# 33     Nidhi  2016-05-12
# 34     Vivek  2017-07-31
# 35     Seema  2021-10-15
# ...

# %%
df[['ename','doj']].loc[45:47]
# Out:
#        ename         doj
# eno
# 45   Sanjana  2023-03-17
# 46     Manoj  2019-07-24
# 47     Payal  2015-10-10

# %%
df=pd.read_csv('emp.csv',delimiter=',',header=0,nrows=10)

# %%
df
# Out:
#    eno   ename  salary  deptno         doj
# 0   10   Amber    1000      10  2018-05-14
# 1    2    Amar    1000      10  2017-03-22
# 2    8   Sagar    1000      20  2020-11-30
# 3    4  Thomas    1000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10
# 5    6   Smith    1000      10  2016-12-01
# 6    7  Robert    3000      20  2023-06-25
# 7    3    Nick    1000      30  2015-09-15
# 8    9   Naman    4000      30  2020-01-20
# 9    1   Vikas    1000      30  2017-10-03

# %%
df=pd.read_csv('emp.csv',delimiter=',',header=0,skiprows=10,nrows=5)

# %%
df
# Out:
#     1   Vikas   1000  30  2017-10-03
# 0  11  Dennis  41000  30  2024-01-05
# 1  12   Karan   2200  20  2018-06-16
# 2  13  Simran   1500  10  2019-12-19
# 3  14    Amit   2000  30  2022-04-09
# 4  15    Neha   1700  20  2021-07-22

# %%
df = pd.read_csv('emp.csv', delimiter=',', skiprows=range(1, 11), nrows=5)

# %%
df
# Out:
#    eno   ename  salary  deptno         doj
# 0   11  Dennis   41000      30  2024-01-05
# 1   12   Karan    2200      20  2018-06-16
# 2   13  Simran    1500      10  2019-12-19
# 3   14    Amit    2000      30  2022-04-09
# 4   15    Neha    1700      20  2021-07-22

# %%
df = pd.read_csv( 'emp.csv',delimiter=',',skiprows=range(1, 11),nrows=5,usecols=['eno', 'ename', 'salary'] )

# %%
df
# Out:
#    eno   ename  salary
# 0   11  Dennis   41000
# 1   12   Karan    2200
# 2   13  Simran    1500
# 3   14    Amit    2000
# 4   15    Neha    1700

# %%
df.dtypes
# Out:
# eno        int64
# ename     object
# salary     int64
# dtype: object

# %%
df = pd.read_csv( 'emp.csv',delimiter=',',skiprows=range(1, 11),nrows=5,usecols=[0,2,3] )

# %%
df
# Out:
#    eno  salary  deptno
# 0   11   41000      30
# 1   12    2200      20
# 2   13    1500      10
# 3   14    2000      30
# 4   15    1700      20

# %%
df.dtypes
# Out:
# eno       int64
# salary    int64
# deptno    int64
# dtype: object

# %%
df=pd.read_csv('emp.csv',dtype={'eno':object})

# %%
df.dtypes
# Out:
# eno       object
# ename     object
# salary     int64
# deptno     int64
# doj       object
# dtype: object

# %%
df=pd.read_csv('emp.csv',parse_dates=['doj'])

# %%
df.dtypes
# Out:
# eno                int64
# ename             object
# salary             int64
# deptno             int64
# doj       datetime64[ns]
# dtype: object

# %%
df= pd.to_datetime(df['doj'], format='%Y-%m-%d')

# %%
df
# Out:
# 0    2018-05-14
# 1    2017-03-22
# 2    2020-11-30
# 3    2019-08-18
# 4    2021-02-10
# 5    2016-12-01
# 6    2023-06-25
# 7    2015-09-15
# 8    2020-01-20
# 9    2017-10-03
# 10   2024-01-05
# 11   2018-06-16
# 12   2019-12-19
# 13   2022-04-09
# 14   2021-07-22
# 15   2016-03-28
# 16   2015-11-11
# 17   2020-09-04
# 18   2023-08-07
# 19   2018-10-29
# 20   2022-12-14
# 21   2017-02-17
# 22   2019-05-21
# 23   2016-07-30
# 24   2020-03-13
# 25   2021-09-25
# 26   2019-01-06
# 27   2015-04-17
# 28   2023-02-11
# 29   2018-09-09
# 30   2022-11-03
# 31   2020-06-26
# 32   2016-05-12
# 33   2017-07-31
# 34   2021-10-15
# 35   2023-05-01
# 36   2015-08-22
# 37   2019-03-02
# 38   2022-02-05
# 39   2020-07-19
# 40   2018-12-28
# 41   2021-01-09
# 42   2017-11-14
# 43   2016-06-08
# 44   2023-03-17
# 45   2019-07-24
# 46   2015-10-10
# Name: doj, dtype: datetime64[ns]

# %%
df.dt.month
# Out:
# 0      5
# 1      3
# 2     11
# 3      8
# 4      2
# 5     12
# 6      6
# 7      9
# 8      1
# 9     10
# 10     1
# 11     6
# 12    12
# 13     4
# 14     7
# 15     3
# 16    11
# 17     9
# 18     8
# 19    10
# 20    12
# 21     2
# 22     5
# 23     7
# 24     3
# 25     9
# 26     1
# 27     4
# 28     2
# 29     9
# 30    11
# 31     6
# 32     5
# 33     7
# 34    10
# 35     5
# 36     8
# 37     3
# 38     2
# 39     7
# 40    12
# 41     1
# 42    11
# 43     6
# 44     3
# 45     7
# 46    10
# Name: doj, dtype: int32

# %%
for i in pd.read_csv('emp.csv',chunksize=10):
    print(i)
# Out:
#    eno   ename  salary  deptno         doj
# 0   10   Amber    1000      10  2018-05-14
# 1    2    Amar    1000      10  2017-03-22
# 2    8   Sagar    1000      20  2020-11-30
# 3    4  Thomas    1000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10
# 5    6   Smith    1000      10  2016-12-01
# 6    7  Robert    3000      20  2023-06-25
# 7    3    Nick    1000      30  2015-09-15
# 8    9   Naman    4000      30  2020-01-20
# 9    1   Vikas    1000      30  2017-10-03
#     eno   ename  salary  deptno         doj
# 10   11  Dennis   41000      30  2024-01-05
# 11   12   Karan    2200      20  2018-06-16
# 12   13  Simran    1500      10  2019-12-19
# 13   14    Amit    2000      30  2022-04-09
# 14   15    Neha    1700      20  2021-07-22
# 15   16   Rahul    1200      10  2016-03-28
# 16   17   Divya    3000      30  2015-11-11
# 17   18  Rakesh    1800      10  2020-09-04
# 18   19  Monica    2500      20  2023-08-07
# ...

# %%
import chardet

with open("emp.csv", "rb") as f:
    result = chardet.detect(f.read(10000))

print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import chardet
#       3 with open("emp.csv", "rb") as f:
#       4     result = chardet.detect(f.read(10000))
#
# ModuleNotFoundError: No module named 'chardet'
