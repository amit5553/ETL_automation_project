# %%
import pandas as pd

# %%
df=pd.read_csv('employees.csv')

# %%
df
# Out:
#    eid   ename    city
# 0    1    amit     kop
# 1    2   kumar   kagal
# 2    3   vijay    pune
# 3    4  ramesh     mum
# 4    5    ravi  satara

# %%
df1=pd.read_csv('salary.csv')

# %%
df1
# Out:
#    eid   dept
# 0    1     it
# 1    2   mech
# 2    3  civil
# 3    6  elect
# 4    7     ai

# %%
df.merge(df1,on='eid',how='inner')
# Out:
#    eid  ename   city   dept
# 0    1   amit    kop     it
# 1    2  kumar  kagal   mech
# 2    3  vijay   pune  civil

# %%
df.merge(df1,on='eid',how='left')
# Out:
#    eid   ename    city   dept
# 0    1    amit     kop     it
# 1    2   kumar   kagal   mech
# 2    3   vijay    pune  civil
# 3    4  ramesh     mum    NaN
# 4    5    ravi  satara    NaN

# %%
df.merge(df1,on='eid',how='right')
# Out:
#    eid  ename   city   dept
# 0    1   amit    kop     it
# 1    2  kumar  kagal   mech
# 2    3  vijay   pune  civil
# 3    6    NaN    NaN  elect
# 4    7    NaN    NaN     ai

# %%
joins=df.merge(df1,on='eid',how='outer')

# %%
joins
# Out:
#    eid   ename    city   dept
# 0    1    amit     kop     it
# 1    2   kumar   kagal   mech
# 2    3   vijay    pune  civil
# 3    4  ramesh     mum    NaN
# 4    5    ravi  satara    NaN
# 5    6     NaN     NaN  elect
# 6    7     NaN     NaN     ai

# %%
joins.isnull().sum()
# Out:
# eid      0
# ename    2
# city     2
# dept     2
# dtype: int64

# %%
joins[joins.isnull().any(axis=1)]
# Out:
#    eid   ename    city   dept
# 3    4  ramesh     mum    NaN
# 4    5    ravi  satara    NaN
# 5    6     NaN     NaN  elect
# 6    7     NaN     NaN     ai

# %%
joins[joins.isna().any(axis=1)]
# Out:
#    eid   ename    city   dept
# 3    4  ramesh     mum    NaN
# 4    5    ravi  satara    NaN
# 5    6     NaN     NaN  elect
# 6    7     NaN     NaN     ai

# %%
df.merge(df1, how='outer', indicator=True)
# Out:
#    eid   ename    city   dept      _merge
# 0    1    amit     kop     it        both
# 1    2   kumar   kagal   mech        both
# 2    3   vijay    pune  civil        both
# 3    4  ramesh     mum    NaN   left_only
# 4    5    ravi  satara    NaN   left_only
# 5    6     NaN     NaN  elect  right_only
# 6    7     NaN     NaN     ai  right_only

# %%
df.merge(df1, how='left', indicator=True)
# Out:
#    eid   ename    city   dept     _merge
# 0    1    amit     kop     it       both
# 1    2   kumar   kagal   mech       both
# 2    3   vijay    pune  civil       both
# 3    4  ramesh     mum    NaN  left_only
# 4    5    ravi  satara    NaN  left_only

# %%
df.merge(df1, how='left', indicator=True).query('_merge == "left_only"').drop('_merge', axis=1)
# Out:
#    eid   ename    city dept
# 3    4  ramesh     mum  NaN
# 4    5    ravi  satara  NaN
