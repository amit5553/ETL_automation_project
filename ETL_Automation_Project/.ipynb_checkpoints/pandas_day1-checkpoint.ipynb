# %%
import pandas as pd

# %%
df=pd.read_csv('emp.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
ser=df['eno']

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# 0     10
# 1      2
# 2      8
# 3      4
# 4      5
# 5      6
# 6      7
# 7      3
# 8      9
# 9      1
# 10    11
# 11    12
# 12    13
# 13    14
# 14    15
# 15    16
# 16    17
# 17    18
# 18    19
# 19    20
# 20    21
# 21    22
# 22    23
# 23    24
# 24    25
# 25    26
# 26    27
# 27    28
# 28    29
# 29    30
# 30    31
# 31    32
# 32    33
# 33    34
# 34    35
# 35    36
# 36    37
# 37    38
# 38    39
# 39    40
# 40    41
# 41    42
# 42    43
# 43    44
# 44    45
# 45    46
# 46    47
# Name: eno, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['eno','ename']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['eno','ename']]
# Out:
#     eno    ename
# 0    10    Amber
# 1     2     Amar
# 2     8    Sagar
# 3     4   Thomas
# 4     5     Jade
# 5     6    Smith
# 6     7   Robert
# 7     3     Nick
# 8     9    Naman
# 9     1    Vikas
# 10   11   Dennis
# 11   12    Karan
# 12   13   Simran
# 13   14     Amit
# 14   15     Neha
# 15   16    Rahul
# 16   17    Divya
# 17   18   Rakesh
# 18   19   Monica
# 19   20     John
# 20   21    Sneha
# 21   22    David
# 22   23    Anita
# 23   24    Vinod
# 24   25    Meena
# 25   26    Harsh
# 26   27   Kavita
# 27   28    Mohan
# 28   29    Priya
# 29   30   Suresh
# 30   31     Rani
# 31   32     Ajay
# 32   33    Nidhi
# 33   34    Vivek
# 34   35    Seema
# 35   36     Ritu
# 36   37    Kunal
# 37   38     Alok
# 38   39   Poonam
# 39   40     Yash
# 40   41     Nina
# 41   42    Tarun
# 42   43    Geeta
# 43   44    Ashok
# 44   45  Sanjana
# 45   46    Manoj
# 46   47    Payal

# %%
df=pd.read_csv('emp.csv',delimiter=',')

# %%
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
df=pd.read_csv('emp.csv',delimiter=',',usecols=['eno','ename'])

# %%
df
# Out:
#     eno    ename
# 0    10    Amber
# 1     2     Amar
# 2     8    Sagar
# 3     4   Thomas
# 4     5     Jade
# 5     6    Smith
# 6     7   Robert
# 7     3     Nick
# 8     9    Naman
# 9     1    Vikas
# 10   11   Dennis
# 11   12    Karan
# 12   13   Simran
# 13   14     Amit
# 14   15     Neha
# 15   16    Rahul
# 16   17    Divya
# 17   18   Rakesh
# 18   19   Monica
# 19   20     John
# 20   21    Sneha
# 21   22    David
# 22   23    Anita
# 23   24    Vinod
# 24   25    Meena
# 25   26    Harsh
# 26   27   Kavita
# 27   28    Mohan
# 28   29    Priya
# 29   30   Suresh
# 30   31     Rani
# 31   32     Ajay
# 32   33    Nidhi
# 33   34    Vivek
# 34   35    Seema
# 35   36     Ritu
# 36   37    Kunal
# 37   38     Alok
# 38   39   Poonam
# 39   40     Yash
# 40   41     Nina
# 41   42    Tarun
# 42   43    Geeta
# 43   44    Ashok
# 44   45  Sanjana
# 45   46    Manoj
# 46   47    Payal
