# %% [markdown]
# # Oracle database connectivity

# %%
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle
import oracledb
oracle_con_cx_oracle = create_engine("oracle+cx_oracle://system:admin@localhost:1521/xe")
oracle_con_oracledb = oracledb.connect(
    user="system",
    password="admin",
    dsn="localhost:1521/xe"
)

mysql_con = create_engine("mysql+pymysql://root:Admin%40143@localhost:3308/feb2026")

# %%
query = """select * from employees"""
# using cx_oracle connection
df1 = pd.read_sql(query,oracle_con_cx_oracle)
# using oracledb
df2 = pd.read_sql("select * from employees",con=oracle_con_oracledb)
# Out:
# C:\Users\hetur\AppData\Local\Temp\ipykernel_44344\120129968.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql("select * from employees",con=oracle_con_oracledb)

# %%
df2
# Out:
#     EMPID          EMPNAME DEPARTMENT    SALARY  MANAGERID JOININGDATE
# 0       1     Anjali Mehta      Sales   68000.0        NaN  2020-03-15
# 1       2      Rahul Singh  Marketing   72000.0        1.0  2019-06-01
# 2       3        Meera Das         HR   90000.0        1.0  2021-01-20
# 3       4              Ali         IT   85000.0        2.0  2018-07-10
# 4       5       Priya Iyer      Sales  100000.0        2.0  2022-02-11
# 5       6       Arjun Nair         IT   95000.0        4.0  2017-09-05
# 6       7     Suresh Patil    Finance   78000.0        1.0  2019-12-01
# 7       8      Neha Kapoor  Marketing   67000.0        2.0  2021-03-22
# 8       9       Amit Verma      Sales   72000.0        5.0  2018-11-15
# 9      10      Kavya Reddy         IT   88000.0        4.0  2020-08-17
# 10     11      Rohan Gupta    Finance   64000.0        7.0  2021-06-05
# 11     12     Pooja Sharma         HR   55000.0        3.0  2022-07-11
# ...

# %%
# Source is csv file and tragte is mysql database. check if all the rows from a column is loaded in to target

# Prepare target
df = pd.read_csv("employees.csv")
df.to_sql("tgt_emp",mysql_con,index=False)
# Out:
# 5

# %%
# Compare between source and target
df_source = pd.read_csv("employees.csv")
df_target = pd.read_sql("""select * from tgt_emp""",mysql_con)

# %%
df_source
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df_target
# Out:
# eno      5
# ename    5
# dtype: int64

# %%
# Check if all the rows are loaded from source to target
#1. Count check between source and target
src_count = df_source['eno'].count()
tgt_count = df_target['eno'].count()
if src_count == tgt_count:
    print("Row count matches - test passed")
else:
       print("Row count mismacthes - test Failed")
# Out:
# Row count matches - test passed

# %%
# 2. Check if there is any extra row in my source which is not loaded in target
df_source[~df_source['eno'].isin(df_target['eno'])]
# Out:
#    eno ename
# 5    6   Ali

# %%
# 3. Check if there is any extra row in my target which is not available in source
# Please complete thr working

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: eno, dtype: bool
